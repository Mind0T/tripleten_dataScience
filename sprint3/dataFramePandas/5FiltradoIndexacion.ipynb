# %% [markdown]
# <div style="display:flex; justify-content:space-around">
#     <img src="./imagenes/3.jpg" width=500/>
#     <img src="./imagenes/4.jpg" width=500>
# </div>

# %% [markdown]
# # **Filtrado**

# %%
'''
Recuerda como recorrias una lista con for 
lista=["Irving",30,15800,"Masculino]
for x in lista:
    if x[2] >14000:
        print(x)
'''

#!En pandas se llama Indexacion logica o booleana

'''
print(df.loc[df["Trabajo:]=="Arquitectura] 
'''
# Out:
# '\nprint(df.loc[df["Trabajo:]=="Arquitectura] \n'

# %%
import pandas as pd
datos=pd.read_csv("C:\ESCOM\Code\DatasScience_TripleTen\sprint3\datos_profesionales.csv")

# %%
datos.head()
# Out:
#              Nombre  Edad  Ingresos (MXN)                     Carrera  \
# 0    Sofía González    50           95444                Arquitectura
# 1     David Jiménez    60           94756  Relaciones Internacionales
# 2  Francisco García    45          102157                Arquitectura
# 3   Sofía Hernández    62           69465                Arquitectura
# 4        Juan Pérez    48          107485                     Derecho
#
#                      Trabajo
# 0   Analista de Comunicación
# 1            Diseñador UX/UI
# 2     Profesor de Secundaria
# 3  Especialista en Marketing
# 4  Desarrollador de Software

# %%
datos_arquitectos=datos.loc[datos["Carrera"] =="Arquitectura"] # filtro a los que estudiaron Arquitectura

# %%
datos_arquitectos_Desarrolladores=datos_arquitectos.loc[(datos_arquitectos.loc[:,"Trabajo"]=="Desarrollador de Software") | (datos_arquitectos["Trabajo"]=="Diseñador UX/UI")]#filtro a los que trabajan en desarrolo de software

# %%
datos_arquitectos.head(50)
# Out:
#                   Nombre  Edad  Ingresos (MXN)       Carrera  \
# 0         Sofía González    50           95444  Arquitectura
# 2       Francisco García    45          102157  Arquitectura
# 3        Sofía Hernández    62           69465  Arquitectura
# 9         Elena González    35          128407  Arquitectura
# 15         María Ramírez    44           10176  Arquitectura
# 20         Ana Hernández    39           37023  Arquitectura
# 21       Javier Martínez    48           18750  Arquitectura
# 46             Ana López    55          101368  Arquitectura
# 61             Ana Pérez    46          135959  Arquitectura
# 65   Francisco Hernández    64          133183  Arquitectura
# 101       Patricia Gómez    45          132589  Arquitectura
# 112          José Flores    59          137230  Arquitectura
# 137        Luis González    64          100412  Arquitectura
# 142      Francisco López    58          142585  Arquitectura
# ...

# %%
datos_arquitectos.shape
# Out:
# (43, 5)

# %%
datos_arquitectos_Desarrolladores.head()
# Out:
#              Nombre  Edad  Ingresos (MXN)       Carrera  \
# 9    Elena González    35          128407  Arquitectura
# 20    Ana Hernández    39           37023  Arquitectura
# 46        Ana López    55          101368  Arquitectura
# 398      Ana Flores    59           94723  Arquitectura
#
#                        Trabajo
# 9    Desarrollador de Software
# 20             Diseñador UX/UI
# 46   Desarrollador de Software
# 398  Desarrollador de Software

# %%
datos_arquitectos_Desarrolladores.shape
# Out:
# (4, 5)
