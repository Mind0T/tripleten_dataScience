# %% [markdown]
# <div style="display:flex; justify-content: space-around;">
#     <img src="./imagenes/1.jpg" width=500/>
#     <img src="./imagenes/2.jpg" width=500/>
# </div>

# %%
#Indexacion DF
'''
Metodo loc
Casi todo es muy intuitivo solo tomar en cuenta desde ya
#! Escoger una celda, Multiples filas consecutivas y Una fila no se pueden con abreviadas

#todo En multiples filas consecutivas en loc no [:,"Nombre":"Trabajo"] no es necesario poner corchetes a las columnas como en las demas llamdas

'''
import pandas as pd

# %%
df=pd.read_csv("C:\ESCOM\Code\DatasScience_TripleTen\sprint3\datos_profesionales.csv")

# %%
df.head()
# Out:
#              Nombre  Edad  Ingresos (MXN)                     Carrera  \
# 0    Sofía González    50           95444                Arquitectura
# 1     David Jiménez    60           94756  Relaciones Internacionales
# 2  Francisco García    45          102157                Arquitectura
# 3   Sofía Hernández    62           69465                Arquitectura
# 4        Juan Pérez    48          107485                     Derecho
#
#                      Trabajo
# 0   Analista de Comunicación
# 1            Diseñador UX/UI
# 2     Profesor de Secundaria
# 3  Especialista en Marketing
# 4  Desarrollador de Software

# %% [markdown]
# ### Una celda

# %%
df.loc[0,'Nombre'] #Notacion completa
# Out:
# 'Sofía González'

# %%
#df[0][0]#Notacion abreviada no se puede

# %% [markdown]
# ### Una columna

# %%
df.loc[:,"Carrera"]
# Out:
# 0                    Arquitectura
# 1      Relaciones Internacionales
# 2                    Arquitectura
# 3                    Arquitectura
# 4                         Derecho
#                   ...
# 495                  Arquitectura
# 496            Contaduría Pública
# 497                     Educación
# 498        Ingeniería en Sistemas
# 499         Ingeniería Industrial
# Name: Carrera, Length: 500, dtype: object

# %%
df["Carrera"]
# Out:
# 0                    Arquitectura
# 1      Relaciones Internacionales
# 2                    Arquitectura
# 3                    Arquitectura
# 4                         Derecho
#                   ...
# 495                  Arquitectura
# 496            Contaduría Pública
# 497                     Educación
# 498        Ingeniería en Sistemas
# 499         Ingeniería Industrial
# Name: Carrera, Length: 500, dtype: object

# %% [markdown]
# ### Columnas Multiples

# %%
df.loc[:,["Nombre","Carrera"]]
# Out:
#                Nombre                     Carrera
# 0      Sofía González                Arquitectura
# 1       David Jiménez  Relaciones Internacionales
# 2    Francisco García                Arquitectura
# 3     Sofía Hernández                Arquitectura
# 4          Juan Pérez                     Derecho
# ..                ...                         ...
# 495    David Martínez                Arquitectura
# 496      Carmen Gómez          Contaduría Pública
# 497  Javier Rodríguez                   Educación
# 498      Javier Pérez      Ingeniería en Sistemas
# 499    Miguel Ramírez       Ingeniería Industrial
#
# [500 rows x 2 columns]

# %%
df[["Nombre","Edad"]]
# Out:
#                Nombre  Edad
# 0      Sofía González    50
# 1       David Jiménez    60
# 2    Francisco García    45
# 3     Sofía Hernández    62
# 4          Juan Pérez    48
# ..                ...   ...
# 495    David Martínez    22
# 496      Carmen Gómez    61
# 497  Javier Rodríguez    57
# 498      Javier Pérez    44
# 499    Miguel Ramírez    44
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Multiples Columnas consecutivas

# %%
df.loc[:,"Edad":"Carrera"]
# Out:
#      Edad  Ingresos (MXN)                     Carrera
# 0      50           95444                Arquitectura
# 1      60           94756  Relaciones Internacionales
# 2      45          102157                Arquitectura
# 3      62           69465                Arquitectura
# 4      48          107485                     Derecho
# ..    ...             ...                         ...
# 495    22           92538                Arquitectura
# 496    61           13920          Contaduría Pública
# 497    57           94198                   Educación
# 498    44           31052      Ingeniería en Sistemas
# 499    44           44492       Ingeniería Industrial
#
# [500 rows x 3 columns]

# %%
# No se puede con notacion abreviada

# %% [markdown]
# ### Una fila

# %%
df.loc[1]
# Out:
# Nombre                         David Jiménez
# Edad                                      60
# Ingresos (MXN)                         94756
# Carrera           Relaciones Internacionales
# Trabajo                      Diseñador UX/UI
# Name: 1, dtype: object

# %%
#No se puede con notacin abreviada

# %% [markdown]
# ### Todas las filas, empezando por la fila dada

# %%
df.loc[495:]
# Out:
#                Nombre  Edad  Ingresos (MXN)                 Carrera  \
# 495    David Martínez    22           92538            Arquitectura
# 496      Carmen Gómez    61           13920      Contaduría Pública
# 497  Javier Rodríguez    57           94198               Educación
# 498      Javier Pérez    44           31052  Ingeniería en Sistemas
# 499    Miguel Ramírez    44           44492   Ingeniería Industrial
#
#                        Trabajo
# 495          Psicólogo Clínico
# 496                Diplomático
# 497        Abogado Corporativo
# 498  Especialista en Marketing
# 499       Consultor Financiero

# %%
df[495:]
# Out:
#                Nombre  Edad  Ingresos (MXN)                 Carrera  \
# 495    David Martínez    22           92538            Arquitectura
# 496      Carmen Gómez    61           13920      Contaduría Pública
# 497  Javier Rodríguez    57           94198               Educación
# 498      Javier Pérez    44           31052  Ingeniería en Sistemas
# 499    Miguel Ramírez    44           44492   Ingeniería Industrial
#
#                        Trabajo
# 495          Psicólogo Clínico
# 496                Diplomático
# 497        Abogado Corporativo
# 498  Especialista en Marketing
# 499       Consultor Financiero

# %% [markdown]
# ### Todas las filas hasta la fila dada

# %%
df.loc[:10 ]#Incluyendo el 10
# Out:
#                 Nombre  Edad  Ingresos (MXN)                     Carrera  \
# 0       Sofía González    50           95444                Arquitectura
# 1        David Jiménez    60           94756  Relaciones Internacionales
# 2     Francisco García    45          102157                Arquitectura
# 3      Sofía Hernández    62           69465                Arquitectura
# 4           Juan Pérez    48          107485                     Derecho
# 5      Francisco Pérez    56           42209                 Gastronomía
# 6      Elena Hernández    43          138193                Comunicación
# 7   Francisco Martínez    42           33393                   Marketing
# 8     Isabel Rodríguez    32           11227                    Medicina
# 9       Elena González    35          128407                Arquitectura
# 10        María García    46           15426                   Marketing
#
#                       Trabajo
# 0    Analista de Comunicación
# ...

# %%
df[:10]#Sin inclur el 10
# Out:
#                Nombre  Edad  Ingresos (MXN)                     Carrera  \
# 0      Sofía González    50           95444                Arquitectura
# 1       David Jiménez    60           94756  Relaciones Internacionales
# 2    Francisco García    45          102157                Arquitectura
# 3     Sofía Hernández    62           69465                Arquitectura
# 4          Juan Pérez    48          107485                     Derecho
# 5     Francisco Pérez    56           42209                 Gastronomía
# 6     Elena Hernández    43          138193                Comunicación
# 7  Francisco Martínez    42           33393                   Marketing
# 8    Isabel Rodríguez    32           11227                    Medicina
# 9      Elena González    35          128407                Arquitectura
#
#                      Trabajo
# 0   Analista de Comunicación
# 1            Diseñador UX/UI
# 2     Profesor de Secundaria
# 3  Especialista en Marketing
# ...

# %% [markdown]
# ### Multiples filas consecutivas

# %%
df.loc[6:10] #Incluyendo el 10
# Out:
#                 Nombre  Edad  Ingresos (MXN)       Carrera  \
# 6      Elena Hernández    43          138193  Comunicación
# 7   Francisco Martínez    42           33393     Marketing
# 8     Isabel Rodríguez    32           11227      Medicina
# 9       Elena González    35          128407  Arquitectura
# 10        María García    46           15426     Marketing
#
#                       Trabajo
# 6                  Arquitecto
# 7              Médico General
# 8    Analista de Comunicación
# 9   Desarrollador de Software
# 10             Chef Ejecutivo

# %%
df[6:10]#Sin inclur el  el 10
# Out:
#                Nombre  Edad  Ingresos (MXN)       Carrera  \
# 6     Elena Hernández    43          138193  Comunicación
# 7  Francisco Martínez    42           33393     Marketing
# 8    Isabel Rodríguez    32           11227      Medicina
# 9      Elena González    35          128407  Arquitectura
#
#                      Trabajo
# 6                 Arquitecto
# 7             Médico General
# 8   Analista de Comunicación
# 9  Desarrollador de Software
